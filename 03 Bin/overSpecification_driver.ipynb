# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append('../02 Fitter')
from over_specification import check_beta, check_rho

# %% [markdown]
# **Beta Testing**
#
# The aim is this overspecification test is to quantify the calibration quality of the Hagan approximations, and how this would be influenced by the particular $\beta$ parameter. With $\beta$ fixed, we calibrate another three parameters: $\alpha$, $\rho$ and $\nu$. We have repeated the calibration using:
#
# $\beta=0,$
#
# $\beta=0.3,$
#
# $\beta=0.5,$
#
# $\beta=0.7,$
#
# $\beta=1.$
#
# We also give the optimal calibration results with $\beta$ being flexible to yield the best optimization results.
#
# As can be seen from the plots below, it seems that $\beta=0.3$ and $\beta=0.5$ give the best fitting performance while the worst is given by $\beta=0$.

# %%
vols=pd.read_csv('../05 Outputs/outvol.csv')
vol_diff=pd.read_csv('../05 Outputs/vol differences.csv')

# %%
check_beta(vols,vol_diff)

# %% [markdown]
# **Rho Testing**
#
# Same calibration process is applied to $\rho$ using:
#
# $\rho=0,$
#
# $\rho=0.3,$
#
# $\rho=0.5,$
#
# $\rho=0.7,$
#
# $\rho=0.9.$
#
# We can see from the plots below that $\rho=0.3$ gives rather poor results while the performances of other values of $\rho$ are similarly satisfactory.

# %%
check_rho(vols,vol_diff)
