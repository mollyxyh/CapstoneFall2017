# %%
import sys
sys.path.append('/Users/huangxingyue/Desktop/NYU MFE/12 Capstone')
from Fitter.fitter import Fitter
from Fitter.over_specification import over_specification, get_check
from Fitter.collinearity import is_pos_def, check_collinearity

# %% [markdown]
# ### The over-specification analysis is taking swaption data of 5Y tenor and 1Y expiry as an example.
#
# ### Hagan lognormal Implementation

# %%
# calibrate the Hagan SABR model to the input data with different equal constraints
fitter=Fitter('market_data.xlsx')

# %%
beta_check=get_check(fitter,[1],[0,0.3,0.5,0.7,1],method='Hagan_ln')
rho_check=get_check(fitter,[2],[0,-0.3,-0.5,-0.7,-0.9],method='Hagan_ln')
vega_check=get_check(fitter,[3],[0.2,0.4,0.6],method='Hagan_ln')

# %% [markdown]
# **Beta Testing**
#
# The aim is this overspecification test is to quantify the calibration quality of the Hagan approximations, and how this would be influenced by the particular $\beta$ parameter. With $\beta$ fixed, we calibrate another three parameters: $\alpha$, $\rho$ and $\nu$. We have repeated the calibration using:
#
# $\beta=0,$
#
# $\beta=0.3,$
#
# $\beta=0.5,$
#
# $\beta=0.7,$
#
# $\beta=1.$
#
# From the plot below, it seems that the main effect of $\beta$ is a change in the smile slope, which tend to get more pronounced as $\beta$ moves from 1 to 0 (representing a switch from lognormal to normal) even if the effect is rather slight.
#
# Of these plotting lines, beta=0.3 yields kind of funky result, which may be related to high nu of 4.258264.

# %%
# conduct over-specification analysis on parameter beta
over_specification(fitter,beta_check,['beta'])

# %%
for fix_no in [0,0.3,0.5,0.7,1]: # print fitted params with beta fixed to specific nos
    results=fitter.calibration(eqc=[[1],[fix_no]])
    print ('params fitted: alpha=%f, beta=%f, rho=%f, nu=%f.'%(results['alpha'][10],results['beta'][10],results['rho'][10],results['nu'][10]))
    check_collinearity(results['jacmat'])
# Out:
# params fitted: alpha=0.007448, beta=0.000000, rho=0.617323, nu=0.333866.
#
# The condition no. of the Hessian Matrix is: 1.34457843294e+22
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.024786, beta=0.300000, rho=-0.362322, nu=0.001000.
#
# The condition no. of the Hessian Matrix is: 1.55390653354e+23
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.054200, beta=0.500000, rho=-0.063913, nu=0.459900.
#
# The condition no. of the Hessian Matrix is: 1.13280042484e+23
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.120813, beta=0.700000, rho=-0.241340, nu=0.525542.
#
# The condition no. of the Hessian Matrix is: 2.63560425463e+22
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.405583, beta=1.000000, rho=-0.433212, nu=0.645106.
#
# The condition no. of the Hessian Matrix is: 1.23037848607e+24
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.

# %% [markdown]
# **Rho Testing**
#
# Same calibration process is applied to $\rho$ using:
#
# $\rho=0,$
#
# $\rho=-0.3,$
#
# $\rho=-0.5,$
#
# $\rho=-0.7,$
#
# $\rho=-0.9.$
#
# The smile curve is relatively steeper and of less convexity for rho closer to -1. And the effects of $\rho$ and of $\beta$ are similar，both are on the smile slope.

# %%
# conduct over-specification analysis on parameter rho
over_specification(fitter, rho_check,['rho'])

# %%
for fix_no in [0,-0.3,-0.5,-0.7,-0.9]: # print fitted params with different equal constraints
    results=fitter.calibration(eqc=[[2],[fix_no]])
    print ('params fitted: alpha=%f, beta=%f, rho=%f, nu=%f.'%(results['alpha'][10],results['beta'][10],results['rho'][10],results['nu'][10]))
    check_collinearity(results['jacmat'])
# Out:
# params fitted: alpha=0.041853, beta=0.435204, rho=0.000000, nu=0.438679.
#
# The condition no. of the Hessian Matrix is: 7.68766065106e+20
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.152858, beta=0.758146, rho=-0.300000, nu=0.538877.
#
# The condition no. of the Hessian Matrix is: 1.43261593762e+21
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.409021, beta=1.000000, rho=-0.500000, nu=0.611575.
#
# The condition no. of the Hessian Matrix is: 6.20999014902e+19
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.417142, beta=1.000000, rho=-0.700000, nu=0.501026.
#
# The condition no. of the Hessian Matrix is: 1.58043445466e+20
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.024300, beta=0.295038, rho=-0.900000, nu=0.001000.
#
# The condition no. of the Hessian Matrix is: 8.37055994983e+22
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.

# %% [markdown]
# **Nu Testing**
#
# Same calibration process is applied to $\nu$ using:
#
# $\nu=0.2,$
#
# $\nu=0.4,$
#
# $\nu=0.6$
#
# Slight impact as vega has on the ivol smile, it does change the smile shape. It seems that higher vega leads to higher ivols for deep-in-the-money and out-of-the-money options.

# %%
# conduct over-specification analysis on parameter vega
over_specification(fitter, vega_check,['nu'])

# %%
for fix_no in [0.2,0.4,0.6]: # print fitted params with different equal constraints
    results=fitter.calibration(eqc=[[3],[fix_no]])
    print ('params fitted: alpha=%f, beta=%f, rho=%f, nu=%f.'%(results['alpha'][10],results['beta'][10],results['rho'][10],results['nu'][10]))
    check_collinearity(results['jacmat'])
# Out:
# params fitted: alpha=0.007482, beta=0.000000, rho=0.889119, nu=0.200000.
#
# The condition no. of the Hessian Matrix is: 1.40789311702e+21
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.021023, beta=0.262372, rho=0.212216, nu=0.400000.
#
# The condition no. of the Hessian Matrix is: 7.96764211046e+21
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.225795, beta=0.855779, rho=-0.335127, nu=0.600000.
#
# The condition no. of the Hessian Matrix is: 5.02750178582e+22
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.

# %% [markdown]
# **Beta and Rho Testing**
#
# Same calibration process is applied to $\beta$ and $\rho$ using:
#
# $\beta=0,\rho=0$
#
# $\beta=0,\rho=0.8$
#
# $\beta=0,\rho=-0.8$
#
# $\beta=0.3,\rho=0$
#
# $\beta=0.3,\rho=0.8$
#
# $\beta=0.3,\rho=-0.8$

# %%
beta_rho_check=get_check(fitter,[1,2],[[0,0],[0,0.8],[0,-0.8],[0.3,0],[0.3,0.8],[0.3,-0.8]],method='Hagan_ln')
over_specification(fitter,beta_rho_check,['beta','rho'])

# %%
for fix_no in [[0,0],[0,0.8],[0,-0.8],[0.3,0],[0.3,0.8],[0.3,-0.8]]: # print fitted params with different equal constraints
    results=fitter.calibration(eqc=[[1,2],fix_no])
    print ('params fitted: alpha=%f, beta=%f, rho=%f, nu=%f.'%(results['alpha'][10],results['beta'][10],results['rho'][10],results['nu'][10]))
    check_collinearity(results['jacmat'])
# Out:
# params fitted: alpha=0.007477, beta=0.000000, rho=0.000000, nu=0.001000.
#
# The condition no. of the Hessian Matrix is: 5.04054891955e+17
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.007476, beta=0.000000, rho=0.800000, nu=0.234259.
#
# The condition no. of the Hessian Matrix is: 1.75356876861e+20
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.007477, beta=0.000000, rho=-0.800000, nu=0.001000.
#
# The condition no. of the Hessian Matrix is: 9.06865529945e+19
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.024614, beta=0.300000, rho=0.000000, nu=0.290490.
#
# The condition no. of the Hessian Matrix is: 2.24643041419e+18
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.024780, beta=0.300000, rho=0.800000, nu=0.008732.
#
# The condition no. of the Hessian Matrix is: 3.33516134245e+20
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.024786, beta=0.300000, rho=-0.800000, nu=0.001000.
#
# The condition no. of the Hessian Matrix is: 1.46898375612e+20
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.

# %% [markdown]
# **Beta and Nu Testing**
#
# Same calibration process is applied to $\beta$ and $\nu$ using:
#
# $\beta=0,\nu=0.25$
#
# $\beta=0.3,\nu=0.25$
#
# $\beta=0.5,\nu=0.25$
#
# $\beta=0.7,\nu=0.25$
#
# $\beta=1,\nu=0.25$

# %%
beta_nu_check=get_check(fitter,[1,3],[[0,0.25],[0.3,0.25],[0.5,0.25],[0.7,0.25],[1,0.25]],method='Hagan_ln')
over_specification(fitter,beta_nu_check,['beta','nu'])

# %%
for fix_no in [[0,0.25],[0.3,0.25],[0.5,0.25],[0.7,0.25],[1,0.25]]: # print fitted params with different equal constraints
    results=fitter.calibration(eqc=[[1,3],fix_no])
    print ('params fitted: alpha=%f, beta=%f, rho=%f, nu=%f.'%(results['alpha'][10],results['beta'][10],results['rho'][10],results['nu'][10]))
    check_collinearity(results['jacmat'])
# Out:
# params fitted: alpha=0.007471, beta=0.000000, rho=0.746956, nu=0.250000.
#
# The condition no. of the Hessian Matrix is: 2.48912077663e+19
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.024640, beta=0.300000, rho=0.116008, nu=0.250000.
#
# The condition no. of the Hessian Matrix is: 6.01793881825e+19
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.055032, beta=0.500000, rho=-0.305038, nu=0.250000.
#
# The condition no. of the Hessian Matrix is: 2.41810605245e+19
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.123715, beta=0.700000, rho=-0.717365, nu=0.250000.
#
# The condition no. of the Hessian Matrix is: 2.36060641963e+20
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.416087, beta=1.000000, rho=-0.999000, nu=0.250000.
#
# The condition no. of the Hessian Matrix is: 5.76631488254e+20
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.

# %% [markdown]
# **Rho and Nu Testing**
#
# Same calibration process is applied to $\rho$ and $\nu$ using:
#
# $\rho=0,\nu=0.25$
#
# $\rho=0.8,\nu=0.25$
#
# $\rho=-0.8,\nu=0.25$

# %%
rho_nu_check=get_check(fitter,[2,3],[[0,0.25],[0.8,0.25],[-0.8,0.25]],method='Hagan_ln')
over_specification(fitter,rho_nu_check,['rho','nu'])

# %%
for fix_no in [[0,0.25],[0.8,0.25],[-0.8,0.25]]: # print fitted params with different equal constraints
    results=fitter.calibration(eqc=[[2,3],fix_no])
    print ('params fitted: alpha=%f, beta=%f, rho=%f, nu=%f.'%(results['alpha'][10],results['beta'][10],results['rho'][10],results['nu'][10]))
    check_collinearity(results['jacmat'])
# Out:
# params fitted: alpha=0.028974, beta=0.340396, rho=0.000000, nu=0.250000.
#
# The condition no. of the Hessian Matrix is: 2.14724961137e+19
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.007476, beta=0.000000, rho=0.800000, nu=0.250000.
#
# The condition no. of the Hessian Matrix is: 1.78460509592e+19
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.
# params fitted: alpha=0.115983, beta=0.683272, rho=-0.800000, nu=0.250000.
#
# The condition no. of the Hessian Matrix is: 1.87968981031e+20
#
# The model may suffer from strong collinearity as the condition no. is greater than 5000.

# %% [markdown]
# ### Hagan normal Implementation

# %%
beta_check=get_check(fitter,1,[0,0.3,0.5,0.7,1],method='Hagan_norm')
rho_check=get_check(fitter,2,[0,-0.3,-0.5,-0.7,-0.9],method='Hagan_norm')
alpha_check=get_check(fitter,0,[0.1,0.3,0.5],method='Hagan_norm')
vega_check=get_check(fitter,3,[0.2,0.4,0.6],method='Hagan_norm')

# %% [markdown]
# ** It seems that ATM verified step has a funky effect on Hagan normal implementation. **

# %%
# conduct over-specification analysis on parameter beta
over_specification(fitter,beta_check)

# %%
over_specification(fitter,rho_check)

# %%
over_specification(fitter,alpha_check)

# %%
over_specification(fitter,vega_check)

# %% [markdown]
# ### Obloj Implementation

# %% [markdown]
# Some ValueError arises for Obloj Implementation, which I haven't found a reason for.

# %%
# calibrate the Obloj SABR model to the input data with different equal constraints
beta_check=get_check(fitter,1,[0,0.3,0.5,0.7,1],method='Obloj')
rho_check=get_check(fitter,2,[0,-0.3,-0.5,-0.7,-0.9],method='Obloj')
alpha_check=get_check(fitter,0,[0.1,0.3,0.5],method='Obloj')
vega_check=get_check(fitter,3,[0.2,0.4,0.6],method='Obloj')
# Out:
# /Users/huangxingyue/Desktop/NYU MFE/12 Capstone/Pricing/SABR.py:89: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma=nu*logFK/math.log((math.sqrt(1-2*rho*z+z*z)+z-rho)/(1-rho))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-3147eb2fbb8e> in <module>()
#       1 # calibrate the Obloj SABR model to the input data with different equal constraints
#       2 beta_check=get_check(fitter,1,[0,0.3,0.5,0.7,1],method='Obloj')
# ----> 3 rho_check=get_check(fitter,2,[0,-0.3,-0.5,-0.7,-0.9],method='Obloj')
#       4 alpha_check=get_check(fitter,0,[0.1,0.3,0.5],method='Obloj')
#       5 vega_check=get_check(fitter,3,[0.2,0.4,0.6],method='Obloj')
#
# /Users/huangxingyue/Desktop/NYU MFE/12 Capstone/Fitter/over_specification.py in get_check(fitter, fix_par, fix_no, method)
#      36     check={}
#      37     for no in fix_no:
# ---> 38         results=fitter.calibration(eqc=[fix_par,no],method=method)
#      39         check[no]=fitter.ivol_SABR(results['alpha'],results['beta'],results['rho'],results['nu'],method=method)
#      40     return check
#
# /Users/huangxingyue/Desktop/NYU MFE/12 Capstone/Fitter/fitter.pyc in calibration(self, starting_par, method, eqc)
#      89             else:
#      90                 res = minimize(self.objfunc, x0, (F[i], K[i], expiry[i], MKT[i], method), bounds=bnds,
# ---> 91                                constraints={'type': 'eq', 'fun': lambda par: par[eqc[0]] - eqc[1]}, method='SLSQP')
#      92
#      93             alpha[i] = res.x[0]
#
# /Users/huangxingyue/anaconda/lib/python2.7/site-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     456     elif meth == 'slsqp':
#     457         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 458                                constraints, callback=callback, **options)
#     459     elif meth == 'dogleg':
#     460         return _minimize_dogleg(fun, x0, args, jac, hess,
#
# /Users/huangxingyue/anaconda/lib/python2.7/site-packages/scipy/optimize/slsqp.pyc in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, **unknown_options)
#     365
#     366             # Compute objective function
# --> 367             fx = func(x)
#     368             # Compute the constraints
#     369             if cons['eq']:
#
# /Users/huangxingyue/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# /Users/huangxingyue/Desktop/NYU MFE/12 Capstone/Fitter/fitter.pyc in objfunc(self, par, F, K, expiry, MKT, method)
#      47             sabr = SABR_model(par[1], par[2], par[3])
#      48             for j in range(len(K)):
# ---> 49                 res += (sabr.ivol_Obloj(par[0],F,K[j],expiry) - MKT[j])**2
#      50         elif method == 'Balland':
#      51             sabr = Balland(par[1], par[2], par[3])
#
# /Users/huangxingyue/Desktop/NYU MFE/12 Capstone/Pricing/SABR.pyc in ivol_Obloj(self, alpha, F, K, expiry)
#      84             elif beta==1:
#      85                 z=nu*logFK/alpha
# ---> 86                 sigma=nu*logFK/math.log((math.sqrt(1-2*rho*z+z*z)+z-rho)/(1-rho))
#      87             else:
#      88                 z=nu*(math.pow(F,(1-beta))-math.pow(K,(1-beta)))/alpha/(1-beta)
#
# ValueError: math domain error
