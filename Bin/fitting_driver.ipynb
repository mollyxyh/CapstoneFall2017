# %%
import xlrd
import math
import numpy as np
from scipy.optimize import minimize
from Fitter.fitting import fitting

# %% [markdown]
# ### Hagan Approximation

# %%
# calibrate the Hagan SABR model to input data
fitting('market_data.xlsx')
# Out:
# Calibrated results of input data:
#
#
#                                           SABR VOLATILITIES
#    	strikes: -150 	-100 	-50 	-25 	ATM 	25 	50 	100 	150
# tenor 	expiry
# 2y 	3m 	2.4628 	1.0223 	0.5411 	0.422 	0.3898 	0.398 	0.4156 	0.4507 	0.4792
# 2y 	6m 	2.2568 	0.9476 	0.5513 	0.4586 	0.4247 	0.4227 	0.4318 	0.4556 	0.4768
# 2y 	9m 	1.8906 	0.8167 	0.5267 	0.4637 	0.4365 	0.4294 	0.4313 	0.4428 	0.4551
# 2y 	1y 	1.5128 	0.6782 	0.4813 	0.4502 	0.4417 	0.4436 	0.4492 	0.4628 	0.4748
# 2y 	2y 	1.8831 	0.886 	0.5778 	0.4912 	0.4403 	0.4207 	0.4209 	0.442 	0.4665
# 2y 	5y 	0.4042 	0.3536 	0.3222 	0.3115 	0.3033 	0.2973 	0.293 	0.2881 	0.2864
# 2y 	10y 	0.3032 	0.2721 	0.2501 	0.2416 	0.2345 	0.2286 	0.2237 	0.2165 	0.2119
# 5y 	3m 	1.1844 	0.6101 	0.4623 	0.4259 	0.403 	0.389 	0.3806 	0.3727 	0.3702
# 5y 	6m 	0.9565 	0.5819 	0.4635 	0.4327 	0.4124 	0.399 	0.3902 	0.3807 	0.3767
# 5y 	9m 	0.8321 	0.5583 	0.4557 	0.427 	0.4072 	0.3934 	0.3838 	0.3727 	0.3674
# ...

# %% [markdown]
# ### Obloj Approximation

# %%
# calibrate the Obloj SABR to the input data
fitting('market_data.xlsx','Obloj')
# Out:
# /Users/huangxingyue/Desktop/NYU MFE/12 Capstone/Pricing/SABR.py:194: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma=par[3]*logFK/math.log((math.sqrt(1-2*par[2]*z+z*z)+z-par[2])/(1-par[2]))
# Calibrated results of input data:
#
#
#                                           SABR VOLATILITIES
#    	strikes: -150 	-100 	-50 	-25 	ATM 	25 	50 	100 	150
# tenor 	expiry
# 2y 	3m 	2.6651 	1.0206 	0.5439 	0.4247 	0.3888 	0.3953 	0.4127 	0.4501 	0.4828
# 2y 	6m 	2.4307 	0.9464 	0.5532 	0.4606 	0.4244 	0.4208 	0.4294 	0.4549 	0.4795
# 2y 	9m 	2.02 	0.8161 	0.5279 	0.4649 	0.4365 	0.4282 	0.4296 	0.4421 	0.4569
# 2y 	1y 	1.5991 	0.6784 	0.4831 	0.4514 	0.4417 	0.4426 	0.448 	0.4625 	0.4768
# 2y 	2y 	2.0718 	0.888 	0.5755 	0.4905 	0.4409 	0.4213 	0.4209 	0.4414 	0.4667
# 2y 	5y 	0.4043 	0.3535 	0.3221 	0.3115 	0.3034 	0.2973 	0.293 	0.288 	0.2864
# 2y 	10y 	0.3032 	0.2721 	0.2501 	0.2416 	0.2345 	0.2286 	0.2237 	0.2165 	0.2119
# ...
