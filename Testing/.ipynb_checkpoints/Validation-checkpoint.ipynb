# %%
import math
import numpy as np
import pandas as pd
import itertools
from Pricing.SABR import SABR_model
from Pricing.pdf_calculation import numerical_pdf
from matplotlib import pyplot as plt
from Pricing.arbitrage_check import arbitrage_check

# %% [markdown]
# #### Sample data

# %%
# Forward Features
expiry=np.array([10,20])
F=np.array([0.02,0.02])
spread = np.arange(0.001,0.1,0.01)
K = [[0 for y in range(len(spread))] for x in range(len(F))]

for i in range(len(F)):
    for j in range(len(spread)):
        K[i][j]=F[i]+spread[j]        
K=np.array(K)   

# Parameters
beta=[0.1,0.9]
rho=[-0.8,0,0.8]
nu=[0.25,0.5]


param_sets = []
for combination in itertools.product(beta, rho, nu):
    param_sets.append(combination)
print('param_sets=',param_sets)
print('number of parameter sets =',len(param_sets))
# Out:
# param_sets= [(0.1, -0.8, 0.25), (0.1, -0.8, 0.5), (0.1, 0, 0.25), (0.1, 0, 0.5), (0.1, 0.8, 0.25), (0.1, 0.8, 0.5), (0.9, -0.8, 0.25), (0.9, -0.8, 0.5), (0.9, 0, 0.25), (0.9, 0, 0.5), (0.9, 0.8, 0.25), (0.9, 0.8, 0.5)]
# number of parameter sets = 12

# %% [markdown]
# #### Lognormal Vols

# %%
ivol = []
for i in range(len(param_sets)):
    sabr=SABR_model(param_sets[i][0],param_sets[i][1],param_sets[i][2])
    alpha = 0.4 * math.pow(F[0],(1-param_sets[i][0]))
    vols = sabr.ivol_matrix(alpha,F,K,expiry,method='Hagan')
    ivol.append(vols)
ivol = [[i] for i in ivol]
print('Lognormal implied vols using Lognormal Hagan:')
ivol
# Out:
# Lognormal implied vols using Lognormal Hagan:
# [[          0         1         2         3         4         5         6  \
#   0  0.399621  0.289907  0.223281  0.183927  0.163182  0.152808  0.147442
#   1  0.412835  0.296165  0.226777  0.186146  0.164760  0.154026  0.148432
#
#             7         8         9
#   0  0.144488  0.142760  0.141690
#   1  0.145319  0.143471  0.142308  ],
#  [          0         1         2         3         4         5         6  \
#   0  0.389506  0.250594  0.199964  0.192968  0.195439  0.199548  0.203619
#   1  0.397473  0.253539  0.201488  0.193993  0.196200  0.200141  0.204097
#
#             7         8         9
#   0  0.207271  0.210451  0.213193
#   1  0.207668  0.210788  0.213487  ],
#  [          0         1         2         3         4         5         6  \
#   0  0.431953  0.361549  0.325366  0.304477  0.291201  0.282050  0.275309
#   1  0.472560  0.390939  0.349575  0.325808  0.310728  0.300342  0.292697
#
#             7         8         9
#   0  0.270069  0.265821  0.262258
#   1  0.286765  0.281964  0.277947  ],
#  [          0         1         2         3         4         5         6  \
#   0  0.493340  0.433157  0.419053  0.417033  0.418052  0.419665  0.421171
#   1  0.595144  0.518323  0.499241  0.495451  0.495706  0.496914  0.498154
#
#             7         8         9
#   0  0.422382  0.423276  0.423879
#   1  0.499157  0.499862  0.500282  ],
#  [          0         1         2         3         4         5         6  \
#   0  0.425213  0.390025  0.370247  0.356973  0.347094  0.339241  0.332716
#   1  0.454263  0.410325  0.386144  0.370195  0.358502  0.349332  0.341802
#
#             7         8         9
#   0  0.327124  0.322221  0.317847
#   1  0.335416  0.329867  0.324957  ],
#  [          0         1         2         3         4         5         6  \
#   0  0.440808  0.444195  0.448020  0.450343  0.451444  0.451689  0.451347
#   1  0.480569  0.476172  0.475598  0.474966  0.473899  0.472466  0.470777
#
#             7         8         9
#   0  0.450601  0.449573  0.448350
#   1  0.468917  0.466950  0.464921  ],
#  [          0         1         2         3         4         5         6  \
#   0  0.324458  0.287768  0.262850  0.245456  0.233426  0.225307  0.219995
#   1  0.254766  0.227411  0.208651  0.195510  0.186441  0.180371  0.176466
#
#             7         8         9
#   0  0.216653  0.214678  0.213644
#   1  0.174087  0.172764  0.172168  ],
#  [          0         1         2         3         4         5         6  \
#   0  0.252983  0.203111  0.180722  0.176919  0.180448  0.186186  0.192408
#   1  0.116686  0.096967  0.088304  0.087955  0.090947  0.094904  0.099018
#
#             7         8         9
#   0  0.198536  0.204378  0.209880
#   1  0.103019  0.106824  0.110412  ],
#  [          0         1         2         3         4         5         6  \
#   0  0.420138  0.417195  0.419979  0.424579  0.429674  0.434771  0.439683
#   1  0.441188  0.438089  0.441005  0.445831  0.451176  0.456525  0.461679
#
#             7         8         9
#   0  0.444344  0.448740  0.452879
#   1  0.466571  0.471185  0.475528  ],
#  [          0         1         2         3         4         5         6  \
#   0  0.482720  0.495891  0.522009  0.547761  0.570861  0.591273  0.609366
#   1  0.566167  0.581606  0.612233  0.642430  0.669518  0.693454  0.714671
#
#             7         8         9
#   0  0.625527  0.640082  0.653295
#   1  0.733622  0.750690  0.766183  ],
#  [          0         1         2         3         4         5         6  \
#   0  0.477541  0.512868  0.537770  0.556808  0.572132  0.584907  0.595831
#   1  0.551177  0.590667  0.618391  0.639519  0.656479  0.670585  0.682624
#
#             7         8         9
#   0  0.605354  0.613781  0.621329
#   1  0.693101  0.702357  0.710636  ],
#  [          0         1         2         3         4         5         6  \
#   0  0.559273  0.650816  0.713269  0.759883  0.796773  0.827147  0.852873
#   1  0.709757  0.823502  0.900630  0.957921  1.003085  1.040148  1.071450
#
#             7         8         9
#   0  0.875129  0.894700  0.912138
#   1  1.098461  1.122162  1.143237  ]]

# %% [markdown]
# #### PDF and CDF

# %%
for i in range(len(param_sets)):
    arb=arbitrage_check(param_sets[i][0],param_sets[i][1],param_sets[i][2])
    alpha = 0.4 * math.pow(F[0],(1-param_sets[i][0]))
    print('beta=',param_sets[i][0],'rho=',param_sets[i][1],'nu=',param_sets[i][2])
    arb.arbitrage(0.001,F,K,expiry,0,1,0.0001,'Hagan','lognormal')
# Out:
# beta= 0.1 rho= -0.8 nu= 0.25
# SABR volatility method: Hagan
# volatility distribution: lognormal
# Expiry= 10 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.051 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.061 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.071 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.081 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.091 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.101 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.111 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.051 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.061 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.071 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.081 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.091 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.101 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.111 c.d.f= 0.0 p.d.f= 0.0 Yes
# beta= 0.1 rho= -0.8 nu= 0.5
# SABR volatility method: Hagan
# volatility distribution: lognormal
# Expiry= 10 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.051 c.d.f= -2.11562789509e-242 p.d.f= -1.75759965113e-238 Yes
# Expiry= 10 Strike price= 0.061 c.d.f= -4.5896905824e-186 p.d.f= -2.81669306678e-182 Yes
# Expiry= 10 Strike price= 0.071 c.d.f= -1.15122208395e-153 p.d.f= -5.11472339339e-150 Yes
# Expiry= 10 Strike price= 0.081 c.d.f= -1.02849494456e-132 p.d.f= -3.37393753937e-129 Yes
# Expiry= 10 Strike price= 0.091 c.d.f= -4.43823748138e-118 p.d.f= -1.10580206623e-114 Yes
# Expiry= 10 Strike price= 0.101 c.d.f= -2.77701638853e-107 p.d.f= -5.40108739631e-104 Yes
# Expiry= 10 Strike price= 0.111 c.d.f= -5.46787311853e-99 p.d.f= -8.50538443731e-96 Yes
# Expiry= 20 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.051 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.061 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.071 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.081 c.d.f= -4.19736308572e-305 p.d.f= -2.33882835622e-301 Yes
# Expiry= 20 Strike price= 0.091 c.d.f= -4.09469525091e-275 p.d.f= -1.81827628502e-271 Yes
# Expiry= 20 Strike price= 0.101 c.d.f= -5.26840517022e-253 p.d.f= -1.88429498837e-249 Yes
# Expiry= 20 Strike price= 0.111 c.d.f= -4.80965479476e-236 p.d.f= -1.4046344337e-232 Yes
# beta= 0.1 rho= 0 nu= 0.25
# SABR volatility method: Hagan
# volatility distribution: lognormal
# Expiry= 10 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.051 c.d.f= -3.13545462874e-292 p.d.f= -2.5165288801e-288 Yes
# Expiry= 10 Strike price= 0.061 c.d.f= -1.07807541521e-238 p.d.f= -6.57487200529e-235 Yes
# Expiry= 10 Strike price= 0.071 c.d.f=
Yes
# Expiry= 20 Strike price= 0.111 c.d.f= -3.01020468825e-103 p.d.f= -3.18439128591e-100 Yes
# beta= 0.9 rho= -0.8 nu= 0.25
# SABR volatility method: Hagan
# volatility distribution: lognormal
# Expiry= 10 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.051 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.061 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.071 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.081 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.091 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.101 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.111 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.051 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.061 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.071 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.081 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.091 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.101 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.111 c.d.f= 0.0 p.d.f= 0.0 Yes
# beta= 0.9 rho= -0.8 nu= 0.5
# SABR volatility method: Hagan
# volatility distribution: lognormal
# Expiry= 10 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.051 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.061 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.071 c.d.f= -6.67873212894e-291 p.d.f= -5.19215518606e-287 Yes
# Expiry= 10 Strike price= 0.081 c.d.f= -5.32019785783e-238 p.d.f= -3.34484610462e-234 Yes
# Expiry= 10 Strike price= 0.091 c.d.f= -6.75722393962e-202 p.d.f= -3.40046427102e-198 Yes
# Expiry= 10 Strike price= 0.101 c.d.f= -9.35470504368e-176 p.d.f= -3.78912908011e-172 Yes
# Expiry= 10 Strike price= 0.111 c.d.f= -5.56887094157e-156 p.d.f= -1.83687954332e-152 Yes
# Expiry= 20 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.051 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.061 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.071 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.081 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.091 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.101 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.111 c.d.f= 0.0 p.d.f= 0.0 Yes
# beta= 0.9 rho= 0 nu= 0.25
# SABR volatility method: Hagan
# volatility distribution: lognormal
# Expiry= 10 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.051 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.061 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.071 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.081 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.091 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.101 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.111 c.d.f= -5.95605679306e-308 p.d.f= -3.18575760162e-304 Yes
# Expiry= 20 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.051 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.061 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.071 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.081 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.091 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.101 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.111 c.d.f= 0.0 p.d.f= 0.0 Yes
# beta= 0.9 rho= 0 nu= 0.5
# SABR volatility method: Hagan
# volatility distribution: lognormal
# Expiry= 10 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.051 c.d.f= -4.55263736327e-237 p.d.f= -4.01282864909e-233 Yes
# Expiry= 10 Strike price= 0.061 c.d.f= -1.17287562098e-170 p.d.f= -7.82480445112e-167 Yes
# Expiry= 10 Strike price= 0.071 c.d.f= -1.1709888757e-133 p.d.f= -5.67031919518e-130 Yes
# Expiry= 10 Strike price= 0.081 c.d.f= -2.83872170357e-110 p.d.f= -1.00930190251e-106 Yes
# Expiry= 10 Strike price= 0.091 c.d.f= -3.17980641403e-94 p.d.f= -8.51740702257e-91 Yes
# Expiry= 10 Strike price= 0.101 c.d.f= -1.49583179745e-82 p.d.f= -3.10108589642e-79 Yes
# Expiry= 10 Strike price= 0.111 c.d.f= -1.08827407355e-73 p.d.f= -1.78965358159e-70 Yes
# Expiry= 20 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.051 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.061 c.d.f= -3.54101489207e-281 p.d.f= -2.88426105806e-277 Yes
# Expiry= 20 Strike price= 0.071 c.d.f= -2.77324428261e-224 p.d.f= -1.77583222491e-220 Yes
# Expiry= 20 Strike price= 0.081 c.d.f= -4.8952282073e-188 p.d.f= -2.42428061088e-184 Yes
# Expiry= 20 Strike price= 0.091 c.d.f= -5.56124853868e-163 p.d.f= -2.14896161037e-159 Yes
# Expiry= 20 Strike price= 0.101 c.d.f= -1.22096741857e-144 p.d.f= -3.74420099375e-141 Yes
# Expiry= 20 Strike price= 0.111 c.d.f= -1.24582003281e-130 p.d.f= -3.08799670811e-127 Yes
# beta= 0.9 rho= 0.8 nu= 0.25
# SABR volatility method: Hagan
# volatility distribution: lognormal
# Expiry= 10 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.051 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.061 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.071 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.081 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.091 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.101 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.111 c.d.f= -1.60424843749e-280 p.d.f= -7.95991029233e-277 Yes
# Expiry= 20 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.051 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.061 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.071 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.081 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.091 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.101 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.111 c.d.f= 0.0 p.d.f= 0.0 Yes
# beta= 0.9 rho= 0.8 nu= 0.5
# SABR volatility method: Hagan
# volatility distribution: lognormal
# Expiry= 10 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 10 Strike price= 0.051 c.d.f= -9.56831882862e-281 p.d.f= -8.77286764842e-277 Yes
# Expiry= 10 Strike price= 0.061 c.d.f= -5.0415883188e-203 p.d.f= -3.65641421257e-199 Yes
# Expiry= 10 Strike price= 0.071 c.d.f= -1.80020164574e-159 p.d.f= -9.76029788176e-156 Yes
# Expiry= 10 Strike price= 0.081 c.d.f= -7.90953129641e-132 p.d.f= -3.20865070016e-128 Yes
# Expiry= 10 Strike price= 0.091 c.d.f= -8.55481273293e-113 p.d.f= -2.64754587188e-109 Yes
# Expiry= 10 Strike price= 0.101 c.d.f= -6.49232575649e-99 p.d.f= -1.56885997926e-95 Yes
# Expiry= 10 Strike price= 0.111 c.d.f= -2.36554655374e-88 p.d.f= -4.56382931246e-85 Yes
# Expiry= 20 Strike price= 0.021 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.031 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.041 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.051 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.061 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.071 c.d.f= 0.0 p.d.f= 0.0 Yes
# Expiry= 20 Strike price= 0.081 c.d.f= -1.72375375567e-301 p.d.f= -1.14472901738e-297 Yes
# Expiry= 20 Strike price= 0.091 c.d.f= -1.88612401292e-261 p.d.f= -1.02298320166e-257 Yes
# Expiry= 20 Strike price= 0.101 c.d.f= -4.62330909532e-232 p.d.f= -2.05420252257e-228 Yes
# Expiry= 20 Strike price= 0.111 c.d.f= -1.45414872142e-209 p.d.f= -5.34266876312e-206 Yes
